# %%
ls /kaggle/input/datasets/akshatsharma1011/graphrag-code-2/GraphRAG-Social-Intelligence-System-main

# %%
# !cp -r /kaggle/input/datasets/akshatsharma1011/graphrag-code-2/GraphRAG-Social-Intelligence-System-main /kaggle/working/

# %%
pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 && pip install -q torch-geometric numpy scipy scikit-learn pytest

# %%
ls

# %%
import os
import zipfile

# ─── Download dataset ───
# !wget -q https://snap.stanford.edu/data/facebook_large.zip

# ─── Create target folder ───
extract_path = "/kaggle/working/data/facebook"
os.makedirs(extract_path, exist_ok=True)

# ─── Extract correctly ───
with zipfile.ZipFile("facebook_large.zip", 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset ready at:", extract_path)

# ─── Show files ───
print(os.listdir(extract_path))

# %%
pwd

# %%
# !mv /kaggle/working/data/facebook/facebook_large/* /kaggle/working/data/facebook/ && \
rm -rf /kaggle/working/data/facebook/facebook_large

# %%
ls

# %%
# !mv /kaggle/working/data /kaggle/working/GraphRAG-Social-Intelligence-System-main/

# %%
cd GraphRAG-Social-Intelligence-System-main

# %%
# %cd /kaggle/working/GraphRAG-Social-Intelligence-System-main

# %%
# !cp '/kaggle/input/datasets/akshatsharma1011/new-testing-pipeline/testing_pipeline_accuracy.py' \
'/kaggle/working/GraphRAG-Social-Intelligence-System-main/tests/testing_pipeline_accuracy_2.py'

# %%
# %cd /kaggle/working/GraphRAG-Social-Intelligence-System-main
# !PYTHONPATH=$(pwd) python tests/testing_pipeline_accuracy_2.py
# Out:
# /kaggle/working/GraphRAG-Social-Intelligence-System-main
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/GraphRAG-Social-Intelligence-System-main
# configfile: pytest.ini
# plugins: anyio-4.12.1, langsmith-0.7.6, typeguard-4.5.1
# collected 1 item
#
# tests/testing_pipeline_accuracy_2.py::test_facebook_pipeline_beats_gnn_stratified_target PASSED [100%]
#
# =============================== warnings summary ===============================
# ../../../usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290
#   /usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290: PytestAssertRewriteWarning: Module already imported so cannot be rewritten; anyio
#     self._mark_plugins_for_rewrite(hook, disable_autoload)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ...

# %%
import json

with open('../pipeline_accuracy_results.json') as f:
    data = json.load(f)

print(data["acc_gnn_test"])
# Out:
# 0.9483756119270138
